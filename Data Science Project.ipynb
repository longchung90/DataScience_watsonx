# %% [markdown]
# ## My Jupyter Notebook on IBM watsonx.ai

# %% [markdown]
# _I am interested in Data Science because I recognise the value in data that can bring in positive impacts to our society and will give me a new career._

# %% [markdown]
# ### This code contains the key to bring down the Entity before it brings down the world.
# **Remember:** _The key must be destroyed together with the Entity_

# %%
c=" Misson"
r=" impossible"
u=" -"
i=" the"
s=" final"
e=" reckoning"

Tom="Watch"

print(Tom + c + r + u +i + s + e)
# Out:
# Watch Misson impossible - the final reckoning

# %% [markdown]
# ##### Each key comoponent has to be accurately entered to reach the final text as ***Mission impossible - the final reckoning*** at Event cinemas.
# ### Good luck!! ![Mission-Impossible-The-Final-Reckoning-Poster.jpg](https://i.postimg.cc/7YB30Mgm/Mission-Impossible-The-Final-Reckoning-Poster.jpg)

# %%
The whole world depends on you!
